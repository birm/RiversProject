# %% [markdown]
# # RiverPredictorModel
#
# This model aims to predict select data from usgs river datasets.
# This version isn't really aiming for performance, just something built on currently limited data.
# It'll be nice to get a wider range of data and come back.

# %% [markdown]
# ## Fetching Data
# Let's use the data utility we've already built for the ingest service.

# %%
import sys
sys.path.insert(1,'../Fetch/')
import WaterServices

# %%
import numpy

# %%
sites = ["02336300", "02336030", "02336093", "02336106"]
print(WaterServices)
res = [WaterServices.getData(x) for x in sites]
# Out:
# <module 'WaterServices' from '../Fetch/WaterServices.py'>
# https://waterdata.usgs.gov/ga/nwis/uv?format=rdb&site_no=02336300&period=1
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# FLOAT ERR
# https://waterdata.usgs.gov/ga/nwis/uv?format=rdb&site_no=02336030&period=1
# https://waterdata.usgs.gov/ga/nwis/uv?format=rdb&site_no=02336093&period=1
# https://waterdata.usgs.gov/ga/nwis/uv?format=rdb&site_no=02336106&period=1

# %%
import pandas
df0 = pandas.DataFrame(res[0])
df1 = pandas.DataFrame(res[1])
df2 = pandas.DataFrame(res[2])
df3 = pandas.DataFrame(res[3])
df0.sort_values(by='datetime')
df1.sort_values(by='datetime')
df2.sort_values(by='datetime')
df3.sort_values(by='datetime')
# Out:
#     agency_cd   site_no          datetime tz_cd  GageHeight  Precipitation
# 0        USGS  02336106  2022-01-12 00:00   EST        2.57            0.0
# 1        USGS  02336106  2022-01-12 00:15   EST        2.57            0.0
# 2        USGS  02336106  2022-01-12 00:30   EST        2.57            0.0
# 3        USGS  02336106  2022-01-12 00:45   EST        2.57            0.0
# 4        USGS  02336106  2022-01-12 01:00   EST        2.57            0.0
# ..        ...       ...               ...   ...         ...            ...
# 177      USGS  02336106  2022-01-13 20:15   EST        2.54            0.0
# 178      USGS  02336106  2022-01-13 20:30   EST        2.54            0.0
# 179      USGS  02336106  2022-01-13 20:45   EST        2.55            0.0
# 180      USGS  02336106  2022-01-13 21:00   EST        2.54            0.0
# 181      USGS  02336106  2022-01-13 21:15   EST        2.55            0.0
#
# [182 rows x 6 columns]

# %%
def toTrainData(df):
    # GageHeight, Precipitation, Temperature, Turbidity
    a = [[x.get('GageHeight', -1), x.get('Precipitation', -1), x.get("Temperature", -1), x.get("Turbidity", -1)] for x in df.to_dict('records')]
    b = numpy.array(a)
    b[b== ''] = -1
    return b.astype(numpy.float32)

# %%
toTrainData(df0)
# Out:
# array([[ 2.6 ,  0.  ,  7.  ,  5.  ],
#        [ 2.59,  0.  ,  6.9 ,  4.9 ],
#        [ 2.59,  0.  ,  6.9 ,  4.9 ],
#        [ 2.59,  0.  ,  6.9 ,  4.9 ],
#        [ 2.59,  0.  ,  6.8 ,  4.9 ],
#        [ 2.59,  0.  ,  6.8 ,  4.6 ],
#        [ 2.59,  0.  ,  6.8 ,  4.7 ],
#        [ 2.59,  0.  ,  6.7 ,  4.7 ],
#        [ 2.59,  0.  ,  6.7 ,  4.8 ],
#        [ 2.59,  0.  ,  6.6 ,  4.9 ],
#        [ 2.59,  0.  ,  6.6 ,  4.8 ],
#        [ 2.59,  0.  ,  6.6 ,  4.5 ],
#        [ 2.59,  0.  ,  6.5 ,  4.4 ],
#        [ 2.59,  0.  ,  6.5 ,  4.9 ],
#        [ 2.59,  0.  ,  6.4 ,  4.7 ],
#        [ 2.59,  0.  ,  6.4 ,  4.7 ],
#        [ 2.6 ,  0.  ,  6.4 ,  4.5 ],
#        [ 2.59,  0.  ,  6.3 ,  4.4 ],
#        [ 2.59,  0.  ,  6.3 ,  4.4 ],
#        [ 2.58,  0.  ,  6.2 ,  4.6 ],
#        [ 2.58,  0.  ,  6.2 ,  4.4 ],
#        [ 2.58,  0.  ,  6.2 ,  4.3 ],
#        [ 2.58,  0.  ,  6.1 ,  4.4 ],
#        [ 2.58,  0.  ,  6.1 ,  4.4 ],
#        [ 2.59,  0.  ,  6.  ,  4.3 ],
#        [ 2.58,  0.  ,  6.  ,  4.2 ],
#        [ 2.59,  0.  ,  6.  ,  4.1 ],
#        [ 2.58,  0.  ,  6.  ,  4.2 ],
#        [ 2.59,  0.  ,  5.9 ,  4.1 ],
#        [ 2.59,  0.  ,  5.9 ,  4.2 ],
#        [ 2.59,  0.  ,  5.8 ,  4.3 ],
#        [ 2.59,  0.  ,  5.8 ,  4.1 ],
#        [ 2.59,  0.  ,  5.8 ,  4.1 ],
#        [ 2.59,  0.  ,  5.8 ,  4.1 ],
#        [ 2.6 ,  0.  ,  5.7 ,  4.1 ],
#        [ 2.59,  0.  ,  5.7 ,  4.  ],
#        [ 2.58,  0.  ,  5.7 ,  4.  ],
#        [ 2.59,  0.  ,  5.7 ,  3.9 ],
#        [ 2.59,  0.  ,  5.7 ,  4.1 ],
#        [ 2.59,  0.  ,  5.8 ,  3.9 ],
#        [ 2.58,  0.  ,  5.8 ,  3.9 ],
#        [ 2.59,  0.  ,  5.9 ,  4.  ],
#        [ 2.59,  0.  ,  6.  ,  3.8 ],
#        [ 2.59,  0.  ,  6.1 ,  4.  ],
#        [ 2.58,  0.  ,  6.2 ,  3.8 ],
#        [ 2.59,  0.  ,  6.3 ,  3.9 ],
#        [ 2.59,  0.  ,  6.4 ,  3.9 ],
#        [ 2.59,  0.  ,  6.5 ,  3.9 ],
#        [ 2.58,  0.  ,  6.7 , -1.  ],
#        [ 2.58,  0.  ,  6.6 , -1.  ],
#        [ 2.58,  0.  , -1.  , -1.  ],
#        [ 2.59,  0.  , -1.  , -1.  ],
#        [ 2.59,  0.  ,  7.1 ,  3.7 ],
#        [ 2.58,  0.  ,  7.2 ,  3.9 ],
#        [ 2.59,  0.  ,  7.3 ,  3.7 ],
#        [ 2.59,  0.  ,  7.4 ,  3.6 ],
#        [ 2.58,  0.  ,  7.5 ,  3.3 ],
#        [ 2.59,  0.  ,  7.6 ,  3.5 ],
#        [ 2.58,  0.  ,  7.7 ,  3.3 ],
#        [ 2.58,  0.  ,  7.7 ,  3.2 ],
#        [ 2.59,  0.  ,  7.8 ,  3.2 ],
#        [ 2.59,  0.  ,  7.8 ,  3.1 ],
#        [ 2.58,  0.  ,  7.8 ,  3.  ],
#        [ 2.59,  0.  ,  7.8 ,  3.  ],
#        [ 2.59,  0.  ,  7.8 ,  2.9 ],
#        [ 2.58,  0.  ,  7.8 ,  2.9 ],
#        [ 2.59,  0.  ,  7.8 ,  2.8 ],
#        [ 2.58,  0.  ,  7.7 ,  2.9 ],
#        [ 2.58,  0.  ,  7.7 ,  2.9 ],
#        [ 2.58,  0.  ,  7.7 ,  3.  ],
#        [ 2.57,  0.  ,  7.6 ,  2.8 ],
#        [ 2.57,  0.  ,  7.6 ,  2.8 ],
#        [ 2.56,  0.  ,  7.5 ,  2.7 ],
#        [ 2.56,  0.  ,  7.4 ,  2.6 ],
#        [ 2.56,  0.  ,  7.4 ,  2.7 ],
#        [ 2.57,  0.  ,  7.3 ,  2.7 ],
#        [ 2.57,  0.  ,  7.3 ,  2.6 ],
#        [ 2.57,  0.  ,  7.2 ,  2.7 ],
#        [ 2.57,  0.  ,  7.2 ,  2.7 ],
#        [ 2.57,  0.  ,  7.2 ,  2.6 ],
#        [ 2.57,  0.  ,  7.2 ,  2.6 ],
#        [ 2.57,  0.  ,  7.1 ,  2.6 ],
#        [ 2.57,  0.  ,  7.1 ,  2.6 ],
#        [ 2.57,  0.  ,  7.1 ,  2.6 ],
#        [ 2.57,  0.  ,  7.1 ,  2.6 ],
#        [ 2.56,  0.  ,  7.  ,  2.7 ],
#        [ 2.56,  0.  ,  7.  ,  2.8 ],
#        [ 2.55,  0.  ,  7.  ,  2.6 ],
#        [ 2.56,  0.  ,  7.  ,  2.8 ],
#        [ 2.55,  0.  ,  7.  ,  2.8 ],
#        [ 2.57,  0.  ,  6.9 ,  2.8 ],
#        [ 2.56,  0.  ,  6.9 ,  2.6 ],
#        [ 2.56,  0.  ,  6.9 ,  2.7 ],
#        [ 2.57,  0.  ,  6.8 ,  2.7 ],
#        [ 2.56,  0.  ,  6.8 ,  2.7 ],
#        [ 2.56,  0.  ,  6.8 ,  2.8 ],
#        [ 2.56,  0.  ,  6.8 ,  2.6 ],
#        [ 2.56,  0.  ,  6.8 ,  2.7 ],
#        [ 2.56,  0.  ,  6.7 ,  2.8 ],
#        [ 2.56,  0.  ,  6.7 ,  2.8 ],
#        [ 2.57,  0.  ,  6.7 ,  2.8 ],
#        [ 2.56,  0.  ,  6.6 ,  2.6 ],
#        [ 2.56,  0.  ,  6.6 ,  2.7 ],
#        [ 2.57,  0.  ,  6.6 ,  2.7 ],
#        [ 2.56,  0.  ,  6.6 ,  2.7 ],
#        [ 2.56,  0.  ,  6.5 ,  2.8 ],
#        [ 2.57,  0.  ,  6.5 ,  2.8 ],
#        [ 2.55,  0.  ,  6.5 ,  2.7 ],
#        [ 2.56,  0.  ,  6.4 ,  2.8 ],
#        [ 2.57,  0.  ,  6.4 ,  2.9 ],
#        [ 2.57,  0.  ,  6.4 ,  2.7 ],
#        [ 2.56,  0.  ,  6.4 ,  2.6 ],
#        [ 2.57,  0.  ,  6.3 ,  2.7 ],
#        [ 2.56,  0.  ,  6.3 ,  2.7 ],
#        [ 2.57,  0.  ,  6.3 ,  2.7 ],
#        [ 2.56,  0.  ,  6.3 ,  2.7 ],
#        [ 2.56,  0.  ,  6.3 ,  2.7 ],
#        [ 2.56,  0.  ,  6.2 ,  2.7 ],
#        [ 2.56,  0.  ,  6.2 ,  2.7 ],
#        [ 2.57,  0.  ,  6.2 ,  2.8 ],
#        [ 2.57,  0.  ,  6.2 ,  2.6 ],
#        [ 2.57,  0.  ,  6.2 ,  2.6 ],
#        [ 2.57,  0.  ,  6.2 ,  2.7 ],
#        [ 2.57,  0.  ,  6.2 ,  2.9 ],
#        [ 2.55,  0.  ,  6.1 ,  2.9 ],
#        [ 2.56,  0.  ,  6.1 ,  2.8 ],
#        [ 2.57,  0.  ,  6.1 ,  2.8 ],
#        [ 2.57,  0.  ,  6.1 ,  2.8 ],
#        [ 2.56,  0.  ,  6.  ,  2.9 ],
#        [ 2.55,  0.  ,  6.  ,  2.8 ],
#        [ 2.56,  0.  ,  6.  ,  2.6 ],
#        [ 2.56,  0.  ,  6.  ,  2.6 ],
#        [ 2.57,  0.  ,  6.1 ,  2.6 ],
#        [ 2.56,  0.  ,  6.1 ,  2.6 ],
#        [ 2.57,  0.  ,  6.1 ,  2.6 ],
#        [ 2.56,  0.  ,  6.2 ,  2.5 ],
#        [ 2.56,  0.  ,  6.2 ,  2.5 ],
#        [ 2.56,  0.  ,  6.3 ,  2.5 ],
#        [ 2.56,  0.  ,  6.4 ,  2.4 ],
#        [ 2.57,  0.  ,  6.5 ,  2.4 ],
#        [ 2.56,  0.  ,  6.6 ,  5.  ],
#        [ 2.56,  0.  ,  6.8 ,  2.3 ],
#        [ 2.57,  0.  ,  6.9 ,  2.2 ],
#        [ 2.56,  0.  ,  7.  ,  2.4 ],
#        [ 2.56,  0.  ,  7.  ,  2.4 ],
#        [ 2.57,  0.  ,  7.2 ,  2.2 ],
#        [ 2.57,  0.  ,  7.3 ,  2.2 ],
#        [ 2.56,  0.  ,  7.3 , 24.9 ],
#        [ 2.56,  0.  ,  7.3 , 10.  ],
#        [ 2.57,  0.  ,  7.4 ,  2.6 ],
#        [ 2.56,  0.  ,  7.5 ,  2.3 ],
#        [ 2.56,  0.  ,  7.7 ,  2.2 ],
#        [ 2.55,  0.  ,  7.8 ,  2.2 ],
#        [ 2.56,  0.  ,  7.9 ,  2.1 ],
#        [ 2.56,  0.  ,  7.9 ,  2.2 ],
#        [ 2.56,  0.  ,  7.9 ,  2.2 ],
#        [ 2.56,  0.  ,  7.9 ,  2.3 ],
#        [ 2.55,  0.  ,  7.9 ,  2.4 ],
#        [ 2.56,  0.  ,  8.  ,  2.5 ],
#        [ 2.55,  0.  ,  8.1 ,  2.3 ],
#        [ 2.56,  0.  ,  8.1 ,  2.2 ],
#        [ 2.55,  0.  ,  8.1 ,  2.2 ],
#        [ 2.55,  0.  ,  8.1 ,  2.2 ],
#        [ 2.56,  0.  ,  8.1 ,  2.3 ],
#        [ 2.55,  0.  ,  8.1 ,  2.2 ],
#        [ 2.55,  0.  ,  8.1 ,  2.2 ],
#        [ 2.55,  0.  ,  8.1 ,  2.1 ],
#        [ 2.55,  0.  ,  8.  ,  2.2 ],
#        [ 2.55,  0.  ,  8.  ,  2.1 ],
#        [ 2.56,  0.  ,  8.  ,  2.2 ],
#        [ 2.56,  0.  ,  8.  ,  2.2 ],
#        [ 2.55,  0.  ,  8.  ,  2.3 ],
#        [ 2.55,  0.  ,  8.  ,  2.3 ],
#        [ 2.55,  0.  ,  8.  ,  2.4 ],
#        [ 2.55,  0.  ,  8.  ,  2.4 ],
#        [ 2.55,  0.  ,  8.  ,  2.6 ],
#        [ 2.55,  0.  ,  8.  ,  2.4 ],
#        [ 2.55,  0.  ,  8.  ,  2.2 ],
#        [ 2.55,  0.  ,  8.  ,  2.3 ],
#        [ 2.55,  0.  ,  8.  ,  2.2 ],
#        [ 2.54,  0.  ,  8.  ,  2.2 ]], dtype=float32)

# %% [markdown]
# ## Model
# Let's use keras, because why not :)
# This data seems to lend itself to a sequence model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled0 = scaler.fit_transform(toTrainData(df0))
scaled1 = scaler.fit_transform(toTrainData(df1))
# df2 isn't useful to us since it has no gage height
scaled3 = scaler.fit_transform(toTrainData(df3))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   """

# %%
def split_sequence(sequence, look_back, forecast_horizon):
 X, y = list(), list()
 for i in range(len(sequence)): 
   lag_end = i + look_back
   forecast_end = lag_end + forecast_horizon
   if forecast_end > len(sequence):
     break
   seq_x, seq_y = sequence[i:lag_end], sequence[lag_end:forecast_end]
   X.append(seq_x)
   y.append(seq_y)
 return numpy.array(X), numpy.array(y)

LOOK_BACK = 20
FORECAST_RANGE = 1
SPLIT = 100

x0,y0 = split_sequence(scaled0[:SPLIT,:], LOOK_BACK, FORECAST_RANGE)
x1,y1 = split_sequence(scaled1[:SPLIT,:], LOOK_BACK, FORECAST_RANGE)
x3,y3 = split_sequence(scaled3[:SPLIT,:], LOOK_BACK, FORECAST_RANGE)
x0t,y0t = split_sequence(scaled0[SPLIT:,:], LOOK_BACK, FORECAST_RANGE)
x1t,y1t = split_sequence(scaled1[SPLIT:,:], LOOK_BACK, FORECAST_RANGE)
x3t,y3t = split_sequence(scaled3[SPLIT:,:], LOOK_BACK, FORECAST_RANGE)
print(x0.shape, x1.shape, x3.shape)
print(y0.shape, y1.shape, y3.shape)
print(x0t.shape, x1t.shape, x3t.shape)
print(y0t.shape, y1t.shape, y3t.shape)
# Out:
# (80, 20, 4) (80, 20, 4) (80, 20, 4)
# (80, 1, 4) (80, 1, 4) (80, 1, 4)
# (61, 20, 4) (61, 20, 4) (62, 20, 4)
# (61, 1, 4) (61, 1, 4) (62, 1, 4)

# %%
model = Sequential()
model.add(LSTM(10, activation='relu', input_shape=(LOOK_BACK, 4)))
model.add(RepeatVector(FORECAST_RANGE))
model.add(LSTM(10, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(4)))
model.compile(loss='mae', optimizer='adam')

# %%
history0 = model.fit(x0, y0, epochs=50, batch_size=20, validation_data=(x0t, y0t), verbose=2, shuffle=False)
history1 = model.fit(x1, y1, epochs=50, batch_size=20, validation_data=(x1t, y1t), verbose=2, shuffle=False)
history3 = model.fit(x3, y3, epochs=50, batch_size=20, validation_data=(x3t, y3t), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 4/4 - 2s - loss: 0.4090 - val_loss: 0.3395
# Epoch 2/50
# 4/4 - 0s - loss: 0.4038 - val_loss: 0.3344
# Epoch 3/50
# 4/4 - 0s - loss: 0.3991 - val_loss: 0.3295
# Epoch 4/50
# 4/4 - 0s - loss: 0.3943 - val_loss: 0.3251
# Epoch 5/50
# 4/4 - 0s - loss: 0.3898 - val_loss: 0.3209
# Epoch 6/50
# 4/4 - 0s - loss: 0.3853 - val_loss: 0.3168
# Epoch 7/50
# 4/4 - 0s - loss: 0.3811 - val_loss: 0.3125
# Epoch 8/50
# 4/4 - 0s - loss: 0.3771 - val_loss: 0.3083
# Epoch 9/50
# 4/4 - 0s - loss: 0.3730 - val_loss: 0.3041
# Epoch 10/50
# 4/4 - 0s - loss: 0.3690 - val_loss: 0.2997
# Epoch 11/50
# 4/4 - 0s - loss: 0.3648 - val_loss: 0.2952
# Epoch 12/50
# 4/4 - 0s - loss: 0.3605 - val_loss: 0.2906
# Epoch 13/50
# 4/4 - 0s - loss: 0.3559 - val_loss: 0.2858
# Epoch 14/50
# 4/4 - 0s - loss: 0.3511 - val_loss: 0.2807
# Epoch 15/50
# 4/4 - 0s - loss: 0.3459 - val_loss: 0.2754
# Epoch 16/50
# 4/4 - 0s - loss: 0.3403 - val_loss: 0.2696
# Epoch 17/50
# 4/4 - 0s - loss: 0.3342 - val_loss: 0.2632
# Epoch 18/50
# 4/4 - 0s - loss: 0.3273 - val_loss: 0.2563
# Epoch 19/50
# 4/4 - 0s - loss: 0.3195 - val_loss: 0.2508
# Epoch 20/50
# 4/4 - 0s - loss: 0.3108 - val_loss: 0.2458
# Epoch 21/50
# 4/4 - 0s - loss: 0.3033 - val_loss: 0.2421
# Epoch 22/50
# 4/4 - 0s - loss: 0.2946 - val_loss: 0.2391
# Epoch 23/50
# 4/4 - 0s - loss: 0.2839 - val_loss: 0.2346
# Epoch 24/50
# 4/4 - 0s - loss: 0.2707 - val_loss: 0.2273
# Epoch 25/50
# 4/4 - 0s - loss: 0.2525 - val_loss: 0.2156
# Epoch 26/50
# 4/4 - 0s - loss: 0.2219 - val_loss: 0.2025
# Epoch 27/50
# 4/4 - 0s - loss: 0.1813 - val_loss: 0.1910
# Epoch 28/50
# 4/4 - 0s - loss: 0.1727 - val_loss: 0.1857
# Epoch 29/50
# 4/4 - 0s - loss: 0.1429 - val_loss: 0.1852
# Epoch 30/50
# 4/4 - 0s - loss: 0.1332 - val_loss: 0.1789
# Epoch 31/50
# 4/4 - 0s - loss: 0.1034 - val_loss: 0.1683
# Epoch 32/50
# 4/4 - 0s - loss: 0.1039 - val_loss: 0.1683
# Epoch 33/50
# 4/4 - 0s - loss: 0.1018 - val_loss: 0.1736
# Epoch 34/50
# 4/4 - 0s - loss: 0.1014 - val_loss: 0.1729
# Epoch 35/50
# 4/4 - 0s - loss: 0.0973 - val_loss: 0.1669
# Epoch 36/50
# 4/4 - 0s - loss: 0.0946 - val_loss: 0.1624
# Epoch 37/50
# 4/4 - 0s - loss: 0.0949 - val_loss: 0.1619
# Epoch 38/50
# 4/4 - 0s - loss: 0.0935 - val_loss: 0.1624
# Epoch 39/50
# 4/4 - 0s - loss: 0.0918 - val_loss: 0.1620
# Epoch 40/50
# 4/4 - 0s - loss: 0.0900 - val_loss: 0.1612
# Epoch 41/50
# 4/4 - 0s - loss: 0.0889 - val_loss: 0.1611
# Epoch 42/50
# 4/4 - 0s - loss: 0.0883 - val_loss: 0.1611
# Epoch 43/50
# 4/4 - 0s - loss: 0.0874 - val_loss: 0.1602
# Epoch 44/50
# 4/4 - 0s - loss: 0.0863 - val_loss: 0.1590
# Epoch 45/50
# 4/4 - 0s - loss: 0.0854 - val_loss: 0.1582
# Epoch 46/50
# 4/4 - 0s - loss: 0.0847 - val_loss: 0.1577
# Epoch 47/50
# 4/4 - 0s - loss: 0.0837 - val_loss: 0.1572
# Epoch 48/50
# 4/4 - 0s - loss: 0.0829 - val_loss: 0.1567
# Epoch 49/50
# 4/4 - 0s - loss: 0.0822 - val_loss: 0.1561
# Epoch 50/50
# 4/4 - 0s - loss: 0.0814 - val_loss: 0.1557
# Epoch 1/50
# 4/4 - 0s - loss: 0.1454 - val_loss: 0.2005
# Epoch 2/50
# 4/4 - 0s - loss: 0.1428 - val_loss: 0.2019
# Epoch 3/50
# 4/4 - 0s - loss: 0.1391 - val_loss: 0.2048
# Epoch 4/50
# 4/4 - 0s - loss: 0.1350 - val_loss: 0.2098
# Epoch 5/50
# 4/4 - 0s - loss: 0.1308 - val_loss: 0.2187
# Epoch 6/50
# 4/4 - 0s - loss: 0.1263 - val_loss: 0.2312
# Epoch 7/50
# 4/4 - 0s - loss: 0.1226 - val_loss: 0.2463
# Epoch 8/50
# 4/4 - 0s - loss: 0.1203 - val_loss: 0.2560
# Epoch 9/50
# 4/4 - 0s - loss: 0.1181 - val_loss: 0.2522
# Epoch 10/50
# 4/4 - 0s - loss: 0.1160 - val_loss: 0.2432
# Epoch 11/50
# 4/4 - 0s - loss: 0.1144 - val_loss: 0.2359
# Epoch 12/50
# 4/4 - 0s - loss: 0.1131 - val_loss: 0.2320
# Epoch 13/50
# 4/4 - 0s - loss: 0.1120 - val_loss: 0.2315
# Epoch 14/50
# 4/4 - 0s - loss: 0.1108 - val_loss: 0.2337
# Epoch 15/50
# 4/4 - 0s - loss: 0.1096 - val_loss: 0.2365
# Epoch 16/50
# 4/4 - 0s - loss: 0.1083 - val_loss: 0.2304
# Epoch 17/50
# 4/4 - 0s - loss: 0.1074 - val_loss: 0.2269
# Epoch 18/50
# 4/4 - 0s - loss: 0.1065 - val_loss: 0.2268
# Epoch 19/50
# 4/4 - 0s - loss: 0.1054 - val_loss: 0.2224
# Epoch 20/50
# 4/4 - 0s - loss: 0.1046 - val_loss: 0.2204
# Epoch 21/50
# 4/4 - 0s - loss: 0.1036 - val_loss: 0.2188
# Epoch 22/50
# 4/4 - 0s - loss: 0.1026 - val_loss: 0.2149
# Epoch 23/50
# 4/4 - 0s - loss: 0.1018 - val_loss: 0.2146
# Epoch 24/50
# 4/4 - 0s - loss: 0.1008 - val_loss: 0.2092
# Epoch 25/50
# 4/4 - 0s - loss: 0.0999 - val_loss: 0.2074
# Epoch 26/50
# 4/4 - 0s - loss: 0.0987 - val_loss: 0.2071
# Epoch 27/50
# 4/4 - 0s - loss: 0.0975 - val_loss: 0.2026
# Epoch 28/50
# 4/4 - 0s - loss: 0.0964 - val_loss: 0.2008
# Epoch 29/50
# 4/4 - 0s - loss: 0.0950 - val_loss: 0.1974
# Epoch 30/50
# 4/4 - 0s - loss: 0.0936 - val_loss: 0.1936
# Epoch 31/50
# 4/4 - 0s - loss: 0.0923 - val_loss: 0.1904
# Epoch 32/50
# 4/4 - 0s - loss: 0.0910 - val_loss: 0.1869
# Epoch 33/50
# 4/4 - 0s - loss: 0.0894 - val_loss: 0.1816
# Epoch 34/50
# 4/4 - 0s - loss: 0.0885 - val_loss: 0.1784
# Epoch 35/50
# 4/4 - 0s - loss: 0.0871 - val_loss: 0.1757
# Epoch 36/50
# 4/4 - 0s - loss: 0.0859 - val_loss: 0.1731
# Epoch 37/50
# 4/4 - 0s - loss: 0.0846 - val_loss: 0.1711
# Epoch 38/50
# 4/4 - 0s - loss: 0.0834 - val_loss: 0.1681
# Epoch 39/50
# 4/4 - 0s - loss: 0.0822 - val_loss: 0.1706
# Epoch 40/50
# 4/4 - 0s - loss: 0.0807 - val_loss: 0.1647
# Epoch 41/50
# 4/4 - 0s - loss: 0.0797 - val_loss: 0.1658
# Epoch 42/50
# 4/4 - 0s - loss: 0.0782 - val_loss: 0.1648
# Epoch 43/50
# 4/4 - 0s - loss: 0.0765 - val_loss: 0.1661
# Epoch 44/50
# 4/4 - 0s - loss: 0.0749 - val_loss: 0.1625
# Epoch 45/50
# 4/4 - 0s - loss: 0.0733 - val_loss: 0.1638
# Epoch 46/50
# 4/4 - 0s - loss: 0.0717 - val_loss: 0.1581
# Epoch 47/50
# 4/4 - 0s - loss: 0.0700 - val_loss: 0.1600
# Epoch 48/50
# 4/4 - 0s - loss: 0.0693 - val_loss: 0.1510
# Epoch 49/50
# 4/4 - 0s - loss: 0.0700 - val_loss: 0.1622
# Epoch 50/50
# 4/4 - 0s - loss: 0.0677 - val_loss: 0.1514
# Epoch 1/50
# 4/4 - 0s - loss: 0.1091 - val_loss: 0.1020
# Epoch 2/50
# 4/4 - 0s - loss: 0.0959 - val_loss: 0.0955
# Epoch 3/50
# 4/4 - 0s - loss: 0.0859 - val_loss: 0.0902
# Epoch 4/50
# 4/4 - 0s - loss: 0.0778 - val_loss: 0.0849
# Epoch 5/50
# 4/4 - 0s - loss: 0.0735 - val_loss: 0.0796
# Epoch 6/50
# 4/4 - 0s - loss: 0.0668 - val_loss: 0.0746
# Epoch 7/50
# 4/4 - 0s - loss: 0.0591 - val_loss: 0.0698
# Epoch 8/50
# 4/4 - 0s - loss: 0.0539 - val_loss: 0.0656
# Epoch 9/50
# 4/4 - 0s - loss: 0.0486 - val_loss: 0.0612
# Epoch 10/50
# 4/4 - 0s - loss: 0.0440 - val_loss: 0.0573
# Epoch 11/50
# 4/4 - 0s - loss: 0.0407 - val_loss: 0.0557
# Epoch 12/50
# 4/4 - 0s - loss: 0.0388 - val_loss: 0.0535
# Epoch 13/50
# 4/4 - 0s - loss: 0.0381 - val_loss: 0.0509
# Epoch 14/50
# 4/4 - 0s - loss: 0.0366 - val_loss: 0.0495
# Epoch 15/50
# 4/4 - 0s - loss: 0.0355 - val_loss: 0.0480
# Epoch 16/50
# 4/4 - 0s - loss: 0.0339 - val_loss: 0.0473
# Epoch 17/50
# 4/4 - 0s - loss: 0.0328 - val_loss: 0.0466
# Epoch 18/50
# 4/4 - 0s - loss: 0.0324 - val_loss: 0.0451
# Epoch 19/50
# 4/4 - 0s - loss: 0.0316 - val_loss: 0.0441
# Epoch 20/50
# 4/4 - 0s - loss: 0.0307 - val_loss: 0.0436
# Epoch 21/50
# 4/4 - 0s - loss: 0.0301 - val_loss: 0.0425
# Epoch 22/50
# 4/4 - 0s - loss: 0.0298 - val_loss: 0.0424
# Epoch 23/50
# 4/4 - 0s - loss: 0.0292 - val_loss: 0.0415
# Epoch 24/50
# 4/4 - 0s - loss: 0.0290 - val_loss: 0.0411
# Epoch 25/50
# 4/4 - 0s - loss: 0.0286 - val_loss: 0.0405
# Epoch 26/50
# 4/4 - 0s - loss: 0.0288 - val_loss: 0.0404
# Epoch 27/50
# 4/4 - 0s - loss: 0.0281 - val_loss: 0.0397
# Epoch 28/50
# 4/4 - 0s - loss: 0.0280 - val_loss: 0.0396
# Epoch 29/50
# 4/4 - 0s - loss: 0.0281 - val_loss: 0.0391
# Epoch 30/50
# 4/4 - 0s - loss: 0.0275 - val_loss: 0.0390
# Epoch 31/50
# 4/4 - 0s - loss: 0.0283 - val_loss: 0.0384
# Epoch 32/50
# 4/4 - 0s - loss: 0.0274 - val_loss: 0.0379
# Epoch 33/50
# 4/4 - 0s - loss: 0.0269 - val_loss: 0.0374
# Epoch 34/50
# 4/4 - 0s - loss: 0.0271 - val_loss: 0.0372
# Epoch 35/50
# 4/4 - 0s - loss: 0.0270 - val_loss: 0.0368
# Epoch 36/50
# 4/4 - 0s - loss: 0.0265 - val_loss: 0.0365
# Epoch 37/50
# 4/4 - 0s - loss: 0.0263 - val_loss: 0.0361
# Epoch 38/50
# 4/4 - 0s - loss: 0.0264 - val_loss: 0.0359
# Epoch 39/50
# 4/4 - 0s - loss: 0.0262 - val_loss: 0.0357
# Epoch 40/50
# 4/4 - 0s - loss: 0.0263 - val_loss: 0.0354
# Epoch 41/50
# 4/4 - 0s - loss: 0.0263 - val_loss: 0.0349
# Epoch 42/50
# 4/4 - 0s - loss: 0.0256 - val_loss: 0.0347
# Epoch 43/50
# 4/4 - 0s - loss: 0.0257 - val_loss: 0.0346
# Epoch 44/50
# 4/4 - 0s - loss: 0.0258 - val_loss: 0.0343
# Epoch 45/50
# 4/4 - 0s - loss: 0.0257 - val_loss: 0.0341
# Epoch 46/50
# 4/4 - 0s - loss: 0.0255 - val_loss: 0.0338
# Epoch 47/50
# 4/4 - 0s - loss: 0.0252 - val_loss: 0.0337
# Epoch 48/50
# 4/4 - 0s - loss: 0.0252 - val_loss: 0.0335
# Epoch 49/50
# 4/4 - 0s - loss: 0.0253 - val_loss: 0.0334
# Epoch 50/50
# 4/4 - 0s - loss: 0.0252 - val_loss: 0.0332

# %%
from matplotlib import pyplot
pyplot.plot(history0.history['loss'], label='train')
pyplot.plot(history0.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(history1.history['loss'], label='train')
pyplot.plot(history1.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(history3.history['loss'], label='train')
pyplot.plot(history3.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## Predictions

# %%
def inverse_transform(y_test, yhat):
 y_test_reshaped = y_test.reshape(-1, y_test.shape[-1])
 yhat_reshaped = yhat.reshape(-1, yhat.shape[-1])
 yhat_inverse = scaler.inverse_transform(yhat_reshaped)
 y_test_inverse = scaler.inverse_transform(y_test_reshaped)
 return yhat_inverse, y_test_inverse

# %%
yhat = model.predict(x1t, verbose=0)
yhat_inverse, y_test_inverse = inverse_transform(y1t, yhat)

# %%
yhat_inverse
# Out:
# array([[ 2.55291533e+00, -3.53573542e-03, -1.02548718e+00,
#         -9.83375430e-01],
#        [ 2.55334091e+00, -7.63983559e-03, -1.03967965e+00,
#         -9.85092521e-01],
#        [ 2.55286932e+00, -1.03708459e-02, -1.03940821e+00,
#         -9.90681589e-01],
#        [ 2.55255914e+00, -1.20196873e-02, -1.04173684e+00,
#         -9.93493140e-01],
#        [ 2.55377197e+00, -1.37061579e-02, -1.06769562e+00,
#         -9.88605559e-01],
#        [ 2.55494261e+00, -1.22521045e-02, -1.07213998e+00,
#         -9.85436916e-01],
#        [ 2.55504847e+00, -1.22954780e-02, -1.06860030e+00,
#         -9.87315655e-01],
#        [ 2.55549407e+00, -1.15223313e-02, -1.06554389e+00,
#         -9.87951875e-01],
#        [ 2.55584764e+00, -1.09825106e-02, -1.06237090e+00,
#         -9.88858104e-01],
#        [ 2.55600739e+00, -1.13036940e-02, -1.06263351e+00,
#         -9.88939345e-01],
#        [ 2.55596399e+00, -1.37033081e-02, -1.06196475e+00,
#         -9.91406262e-01],
#        [ 2.55591583e+00, -1.74605288e-02, -1.06327736e+00,
#         -9.94444370e-01],
#        [ 2.55677652e+00, -2.24760622e-02, -1.07447946e+00,
#         -9.94912565e-01],
#        [ 2.55629015e+00, -2.68832147e-02, -1.07825041e+00,
#         -9.97667849e-01],
#        [ 2.55706668e+00, -2.82593556e-02, -1.07668507e+00,
#         -9.98077571e-01],
#        [ 2.55659032e+00, -2.34354772e-02, -1.05364990e+00,
#         -9.97594774e-01],
#        [ 2.55624700e+00, -2.23378129e-02, -1.03957248e+00,
#         -1.00033915e+00],
#        [ 2.55585623e+00, -1.75588652e-02, -1.02364230e+00,
#         -9.97928083e-01],
#        [ 2.55500031e+00, -5.53677510e-03, -9.92052138e-01,
#         -9.89324450e-01],
#        [ 2.55521297e+00,  6.94309361e-04, -9.76551354e-01,
#         -9.82950568e-01],
#        [ 2.55491567e+00,  1.57433115e-02, -9.39042866e-01,
#         -9.69669402e-01],
#        [ 2.55571222e+00,  2.98087858e-02, -9.04796243e-01,
#         -9.54309702e-01],
#        [ 2.55647516e+00,  4.30960059e-02, -8.67191911e-01,
#         -9.41119730e-01],
#        [ 2.55713177e+00,  5.41995950e-02, -8.32842171e-01,
#         -9.30805266e-01],
#        [ 2.55730462e+00,  6.61097914e-02, -7.89626062e-01,
#         -9.22745705e-01],
#        [ 2.55771232e+00,  7.41320401e-02, -7.65268266e-01,
#         -9.15408909e-01],
#        [ 2.55757380e+00,  7.96500817e-02, -7.42346644e-01,
#         -9.13013816e-01],
#        [ 2.55738759e+00,  8.22459161e-02, -7.30143368e-01,
#         -9.12585497e-01],
#        [ 2.55728292e+00,  8.44347402e-02, -7.20657945e-01,
#         -9.11893964e-01],
#        [ 2.55717707e+00,  8.51909593e-02, -7.15624869e-01,
#         -9.12297606e-01],
#        [ 2.55706239e+00,  8.49570781e-02, -7.13780761e-01,
#         -9.13452685e-01],
#        [ 2.55694699e+00,  8.43085647e-02, -7.11584210e-01,
#         -9.15345073e-01],
#        [ 2.55686045e+00,  8.38445649e-02, -7.08235860e-01,
#         -9.17163670e-01],
#        [ 2.55699205e+00,  8.62436816e-02, -7.05409944e-01,
#         -9.13811088e-01],
#        [ 2.55720973e+00,  8.84113833e-02, -7.00171947e-01,
#         -9.11206782e-01],
#        [ 2.55740905e+00,  8.97829905e-02, -6.95758283e-01,
#         -9.09681559e-01],
#        [ 2.55744815e+00,  8.75137225e-02, -6.86617613e-01,
#         -9.15460348e-01],
#        [ 2.55743766e+00,  8.58347192e-02, -6.78609252e-01,
#         -9.20157552e-01],
#        [ 2.55680585e+00,  7.94414803e-02, -6.75209463e-01,
#         -9.32695687e-01],
#        [ 2.55685830e+00,  8.08726326e-02, -6.66652203e-01,
#         -9.32511866e-01],
#        [ 2.55689383e+00,  8.03551301e-02, -6.61246002e-01,
#         -9.34614658e-01],
#        [ 2.55667210e+00,  7.71058872e-02, -6.55980110e-01,
#         -9.41629112e-01],
#        [ 2.55649018e+00,  7.51191303e-02, -6.50135279e-01,
#         -9.46710229e-01],
#        [ 2.55660701e+00,  7.64236525e-02, -6.44341588e-01,
#         -9.45850909e-01],
#        [ 2.55652142e+00,  7.44922534e-02, -6.39214575e-01,
#         -9.50419545e-01],
#        [ 2.55667567e+00,  7.62517154e-02, -6.33894920e-01,
#         -9.48628485e-01],
#        [ 2.55687547e+00,  7.74656460e-02, -6.28958225e-01,
#         -9.47479248e-01],
#        [ 2.55680776e+00,  7.56760836e-02, -6.24672413e-01,
#         -9.51558948e-01],
#        [ 2.55666900e+00,  7.42289945e-02, -6.22260571e-01,
#         -9.54805493e-01],
#        [ 2.55677223e+00,  7.61199370e-02, -6.21102512e-01,
#         -9.51884747e-01],
#        [ 2.55688643e+00,  7.70071074e-02, -6.21010184e-01,
#         -9.50229824e-01],
#        [ 2.55676198e+00,  7.52004385e-02, -6.20926261e-01,
#         -9.53403294e-01],
#        [ 2.55710292e+00,  8.18346143e-02, -6.22600794e-01,
#         -9.41719830e-01],
#        [ 2.55771232e+00,  8.97911265e-02, -6.22178853e-01,
#         -9.27785695e-01],
#        [ 2.55765700e+00,  8.57545584e-02, -6.19820237e-01,
#         -9.34817433e-01],
#        [ 2.55789304e+00,  9.02414247e-02, -6.22382104e-01,
#         -9.26536262e-01],
#        [ 2.55822062e+00,  9.23993289e-02, -6.17027521e-01,
#         -9.23667908e-01],
#        [ 2.55834699e+00,  9.25594047e-02, -6.15778089e-01,
#         -9.23387587e-01],
#        [ 2.55855751e+00,  9.46485475e-02, -6.13850653e-01,
#         -9.20052052e-01],
#        [ 2.55863309e+00,  9.47131142e-02, -6.13726437e-01,
#         -9.19775009e-01],
#        [ 2.55843782e+00,  9.15797204e-02, -6.12915099e-01,
#         -9.25384521e-01]], dtype=float32)

# %%
print(yhat_inverse[-1,0], y_test_inverse[-1,0]) # prediction vs last observed
df0.iloc[-1]
# Out:
# 2.5584378 2.57
# agency_cd                    USGS
# site_no                  02336300
# datetime         2022-01-13 21:00
# tz_cd                         EST
# Discharge                    42.2
# GageHeight                   2.54
# Temperature                     8
# Conductance                   165
# DO                           10.8
# pH                            7.3
# Turbidity                     2.2
# Precipitation                   0
# Name: 180, dtype: object

# %%
import datetime
print(df0.iloc[-1]['datetime'])
new_time = datetime.datetime.strptime(df0.iloc[-1]['datetime'], "%Y-%m-%d %H:%M") + datetime.timedelta(minutes=15)
str(new_time)
# Out:
# 2022-01-13 21:00
# '2022-01-13 21:15:00'

# %%
prediction_result = {"value": yhat_inverse[-1,0] - y_test_inverse[-1,0], "datetime": new_time, "site": df0.iloc[-1]['site_no'], "type":"gageHeight"}

# %%
print(prediction_result)
# Out:
# {'value': -0.011562109, 'datetime': datetime.datetime(2022, 1, 13, 21, 15), 'site': '02336300', 'type': 'gageHeight'}
